# %% [markdown]
# ## Turning the rdf files into csv files

# %%
#importing the required libraries
import pandas as pd
import os
import glob

#setting the working directory
cd = "C:/Users/hp/Desktop/monday_chall"
